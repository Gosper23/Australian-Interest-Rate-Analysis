# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import panel as pn
pn.extension('plotly')
import plotly.express as px


# %matplotlib inline
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
rba_csv = Path("RBA Cash Rate.csv")
rba_returns = pd.read_csv(rba_csv, index_col="Effective date", parse_dates=True, infer_datetime_format=True)
# rba_returns.describe()
rba_returns.sort_index(ascending = True, inplace = True)
rba_returns.head()
# Out:
#                         Change Cash Rate Target
# Effective date
# 1990-01-23      -0.50 to -1.00   17.00 to 17.50
# 1990-02-15                -0.5   16.50 to 17.00
# 1990-03-07                   0   16.50 to 17.00
# 1990-04-04      -1.00 to -1.50   15.00 to 15.50
# 1990-05-02                   0   15.00 to 15.50

# %%
print(rba_returns.isnull().sum())
print(rba_returns[rba_returns.isnull().any(axis = 1)])
# Out:
# Change              0
# Cash Rate Target    0
# dtype: int64
# Empty DataFrame
# Columns: [Change, Cash Rate Target]
# Index: []

# %%
rba_returns.dropna(inplace=True)
rba_returns.isnull().sum()
# Out:
# Change              0
# Cash Rate Target    0
# dtype: int64

# %%
rba_returns.head()
# Out:
#                         Change Cash Rate Target
# Effective date
# 1990-01-23      -0.50 to -1.00   17.00 to 17.50
# 1990-02-15                -0.5   16.50 to 17.00
# 1990-03-07                   0   16.50 to 17.00
# 1990-04-04      -1.00 to -1.50   15.00 to 15.50
# 1990-05-02                   0   15.00 to 15.50

# %%
rba_sorted_clean = rba_returns.loc['2006-01-01':'2022-05-04']
rba_sorted_clean.head()
# Out:
#                Change Cash Rate Target
# Effective date
# 2006-02-08          0              5.5
# 2006-03-08          0              5.5
# 2006-04-05          0              5.5
# 2006-05-03       0.25             5.75
# 2006-06-07          0             5.75

# %%
rba_sorted_clean.to_csv('rba_sorted_clean.csv')

# %%
gdp_csv = Path("gdp_per_capita.csv")
gdp_per_capita = pd.read_csv(gdp_csv, index_col="Date")
# gdp_returns.describe()
gdp_per_capita.sort_index(ascending = True, inplace = True)
gdp_per_capita.rename(columns = {'GDP per capita':'gdp_per_capita'}, inplace = True)
gdp_per_capita.head()
# Out:
#          gdp_per_capita
# Date
# 1973-09            1041
# 1973-12            1089
# 1974-03            1128
# 1974-06            1167
# 1974-09            1213

# %%
print(gdp_per_capita.isnull().sum())
print(gdp_per_capita[gdp_per_capita.isnull().any(axis =1)])
# Out:
# gdp_per_capita    0
# dtype: int64
# Empty DataFrame
# Columns: [gdp_per_capita]
# Index: []

# %%
gdp_per_capita.dropna(inplace=True)
gdp_per_capita.isnull().sum()
gdp_sorted_clean = gdp_per_capita.loc['2006-01':'2022-05']

gdp_sorted_clean.head()
# Out:
#          gdp_per_capita
# Date
# 2006-03           12353
# 2006-06           12520
# 2006-09           12764
# 2006-12           13050
# 2007-03           13293

# %%
gdp_sorted_clean.to_csv('gdp_sorted_clean.csv')

# %%
unemployment_rate_csv = Path("Unemployment rate.csv")
unemployment_rate = pd.read_csv(unemployment_rate_csv, index_col="Date")

# unemplyoment_returns.describe()
unemployment_rate.sort_index(ascending = True, inplace = True)
unemployment_rate.rename(columns = {'unemployment rate':'unemployment_rate'}, inplace = True)
unemployment_rate.head()
# Out:
#         unemployment_rate
# Date
# 2001-03              6.5%
# 2001-06              6.9%
# 2001-09              6.8%
# 2001-12              6.9%
# 2002-03              6.4%

# %%
unemployment_rate.dropna(inplace=True)
unemployment_rate.isnull().sum()
unemployment_rate_sorted_clean = unemployment_rate.loc['2006-01':'2022-05']
unemployment_rate_sorted_clean.head()
# Out:
#         unemployment_rate
# Date
# 2006-03              4.9%
# 2006-06              4.8%
# 2006-09              4.7%
# 2006-12              4.6%
# 2007-03              4.5%

# %%
unemployment_rate_sorted_clean.to_csv('unemployment_rate_sorted_clean.csv')

# %%
cpi_rate_csv = Path("CPI.csv")
cpi_rate = pd.read_csv(cpi_rate_csv, index_col="Date")
# cpi_rate.describe()
cpi_rate.sort_index(ascending = True, inplace = True)
cpi_rate.head()
# Out:
#          inflation_rate
# Date
# 1922-06             2.8
# 1922-09             2.8
# 1922-12             2.7
# 1923-03             2.7
# 1923-06             2.8

# %%
cpi_rate.dropna(inplace=True)
cpi_rate.isnull().sum()
# Out:
# inflation_rate    0
# dtype: int64

# %%
cpi_rate_sorted_clean = cpi_rate.loc['2006-01':'2022-05']
cpi_rate_sorted_clean.head()
# Out:
#          inflation_rate
# Date
# 2006-03            84.5
# 2006-06            85.9
# 2006-09            86.7
# 2006-12            86.6
# 2007-03            86.6

# %%
cpi_rate_sorted_clean.to_csv('cpi_rate_sorted_clean.csv')

# %%
# quarterly comparison of gdp,cpi and unemplyoment rate.
quarterly_comparison = pd.concat([gdp_sorted_clean, unemployment_rate_sorted_clean, cpi_rate_sorted_clean],axis="columns", join="inner")
quarterly_comparison["unemployment_rate"] = quarterly_comparison["unemployment_rate"].str.replace("%", "", regex=True).astype("float")
quarterly_comparison.head()

# %%
concat_comparison = quarterly_comparison[["gdp_per_capita", "unemployment_rate", "inflation_rate"]]
concat_comparison.head()
# Out:
#          gdp_per_capita  unemployment_rate  inflation_rate
# Date
# 2006-03           12353                4.9            84.5
# 2006-06           12520                4.8            85.9
# 2006-09           12764                4.7            86.7
# 2006-12           13050                4.6            86.6
# 2007-03           13293                4.5            86.6

# %%
concat_comparison.pct_change().dropna()
# Out:
#          gdp_per_capita  unemployment_rate  inflation_rate
# Date
# 2006-06        0.013519          -0.020408        0.016568
# 2006-09        0.019489          -0.020833        0.009313
# 2006-12        0.022407          -0.021277       -0.001153
# 2007-03        0.018621          -0.021739        0.000000
# 2007-06        0.012939          -0.044444        0.012702
# 2007-09        0.011734          -0.023256        0.006842
# 2007-12        0.014387           0.023810        0.009060
# 2008-03        0.020769          -0.046512        0.013468
# 2008-06        0.022260           0.024390        0.014396
# 2008-09        0.016921           0.023810        0.012009
# 2008-12        0.004637           0.069767       -0.003236
# 2009-03       -0.007806           0.239130        0.001082
# 2009-06       -0.010330           0.035088        0.004324
# 2009-09       -0.001313          -0.033898        0.009688
# 2009-12        0.013221          -0.035088        0.005330
# 2010-03        0.023569          -0.018182        0.009544
# 2010-06        0.023360          -0.055556        0.006303
# 2010-09        0.017870           0.000000        0.007307
# 2010-12        0.014288          -0.039216        0.004145
# 2011-03        0.015730           0.000000        0.014448
# 2011-06        0.016854           0.000000        0.009156
# 2011-09        0.010398           0.061224        0.006048
# 2011-12        0.003692           0.000000        0.000000
# 2012-03        0.000784           0.000000        0.001002
# 2012-06        0.001567           0.000000        0.005005
# 2012-09        0.001745           0.057692        0.013944
# 2012-12        0.001321          -0.018182        0.001965
# 2013-03        0.003119           0.037037        0.003922
# 2013-06        0.007116           0.017857        0.003906
# 2013-09        0.009144           0.000000        0.011673
# 2013-12        0.007943           0.035088        0.007692
# 2014-03        0.003444           0.000000        0.005725
# 2014-06       -0.001280           0.016949        0.004744
# 2014-09       -0.002039           0.033333        0.004721
# 2014-12       -0.000584          -0.016129        0.001880
# 2015-03        0.000993           0.000000        0.001876
# 2015-06        0.001167          -0.016393        0.006554
# 2015-09        0.000291           0.016667        0.004651
# 2015-12        0.000932          -0.065574        0.003704
# 2016-03        0.001979           0.000000       -0.001845
# 2016-06        0.007203           0.000000        0.003697
# 2016-09        0.016149          -0.017544        0.007366
# 2016-12        0.017878           0.035714        0.005484
# 2017-03        0.012713           0.017241        0.004545
# 2017-06        0.005121          -0.050847        0.001810
# 2017-09        0.002629          -0.035714        0.006323
# 2017-12        0.006829           0.037037        0.006284
# 2018-03        0.010527           0.000000        0.004460
# 2018-06        0.010955          -0.053571        0.003552
# 2018-09        0.009721          -0.056604        0.004425
# 2018-12        0.008417           0.000000        0.005286
# 2019-03        0.010694           0.020000        0.000000
