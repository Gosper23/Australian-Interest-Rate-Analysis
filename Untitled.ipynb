# %%
# imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
# Set the file path
csv_path = Path("data/joined_ASX_sector_data_rows1.csv")

#set df
joined_ASX_sector_data_rows_df = pd.read_csv(csv_path, index_col="Date")

#test
joined_ASX_sector_data_rows_df.head()
# Out:
#             Utilities  Telecommunication_Services  Industrials  \
# Date
# 12/31/2015    6942.44                     2026.07      4861.33
# 12/30/2015    6927.01                     2026.84      4858.99
# 12/29/2015    6886.45                     2000.18      4805.28
# 12/28/2015    6817.50                     1979.60      4765.90
# 12/24/2015    6859.54                     1974.40      4770.85
#
#             Consumer_Discretionary  Consumer_Staple   Energy  Real Estate  \
# Date
# 12/31/2015                 1995.41          8788.40  8009.88      1291.22
# 12/30/2015                 2002.47          8870.64  8079.95      1313.87
# 12/29/2015                 1985.36          8829.02  7969.35      1309.21
# 12/28/2015                 1957.50          8736.80  7928.40      1291.00
# 12/24/2015                 1948.82          8625.69  7963.86      1304.56
#
#             Financials  Health_Care  Materials  Information_Technology
# Date
# ...

# %%
#Change data type to numeric 
joined_ASX_sector_data_rows_df['Utilities'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Utilities'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Telecommunication_Services'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Telecommunication_Services'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Industrials'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Industrials'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Consumer_Discretionary'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Consumer_Discretionary'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Consumer_Staple'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Consumer_Staple'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Energy'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Energy'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Real Estate'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Real Estate'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Financials'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Financials'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Health_Care'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Health_Care'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Materials'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Materials'], errors='coerce')

# %%
#Change data type to numeric
joined_ASX_sector_data_rows_df['Information_Technology'] = pd.to_numeric(joined_ASX_sector_data_rows_df['Information_Technology'], errors='coerce')

# %%
daily_returns = joined_ASX_sector_data_rows_df.pct_change()
daily_returns.head()
# Out:
#             Utilities  Telecommunication_Services  Industrials  \
# Date
# 12/31/2015        NaN                         NaN          NaN
# 12/30/2015  -0.002223                    0.000380    -0.000481
# 12/29/2015  -0.005855                   -0.013153    -0.011054
# 12/28/2015  -0.010012                   -0.010289    -0.008195
# 12/24/2015   0.006166                   -0.002627     0.001039
#
#             Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# Date
# 12/31/2015                     NaN              NaN       NaN          NaN
# 12/30/2015                0.003538         0.009358  0.008748     0.017542
# 12/29/2015               -0.008544        -0.004692 -0.013688    -0.003547
# 12/28/2015               -0.014033        -0.010445 -0.005138    -0.013909
# 12/24/2015               -0.004434        -0.012717  0.004473     0.010503
#
#             Financials  Health_Care  Materials  Information_Technology
# Date
# ...

# %%
joined_ASX_sector_data_rows_df = joined_ASX_sector_data_rows_df.replace(',','')
joined_ASX_sector_data_rows_df.head()
# Out:
#             Utilities  Telecommunication_Services  Industrials  \
# Date
# 12/31/2015    6942.44                     2026.07      4861.33
# 12/30/2015    6927.01                     2026.84      4858.99
# 12/29/2015    6886.45                     2000.18      4805.28
# 12/28/2015    6817.50                     1979.60      4765.90
# 12/24/2015    6859.54                     1974.40      4770.85
#
#             Consumer_Discretionary  Consumer_Staple   Energy  Real Estate  \
# Date
# 12/31/2015                 1995.41          8788.40  8009.88      1291.22
# 12/30/2015                 2002.47          8870.64  8079.95      1313.87
# 12/29/2015                 1985.36          8829.02  7969.35      1309.21
# 12/28/2015                 1957.50          8736.80  7928.40      1291.00
# 12/24/2015                 1948.82          8625.69  7963.86      1304.56
#
#             Financials  Health_Care  Materials  Information_Technology
# Date
# ...

# %%
joined_ASX_sector_data_rows_df = joined_ASX_sector_data_rows_df.reset_index()

# %%
#
df_split = joined_ASX_sector_data_rows_df["Date"].str.split('/', expand=True)
#
df_split['leftpad'] = df_split[0].str.pad(side='left', fillchar='0', width = 2)
#
df_split["YYYYMM"] = df_split[2] + df_split['leftpad']
#
df_split
#joined_ASX_sector_data_rows and YYYYMM
joined_ASX_sector_data_yyyymm = df_split["YYYYMM"]

# %%
joined_ASX_sector_data_rows = pd.concat([joined_ASX_sector_data_rows_df, joined_ASX_sector_data_yyyymm], axis=1)
joined_ASX_sector_data_rows.head()
# Out:
#          Date  Utilities  Telecommunication_Services  Industrials  \
# 0  12/31/2015    6942.44                     2026.07      4861.33
# 1  12/30/2015    6927.01                     2026.84      4858.99
# 2  12/29/2015    6886.45                     2000.18      4805.28
# 3  12/28/2015    6817.50                     1979.60      4765.90
# 4  12/24/2015    6859.54                     1974.40      4770.85
#
#    Consumer_Discretionary  Consumer_Staple   Energy  Real Estate  Financials  \
# 0                 1995.41          8788.40  8009.88      1291.22     6296.10
# 1                 2002.47          8870.64  8079.95      1313.87     6322.67
# 2                 1985.36          8829.02  7969.35      1309.21     6249.31
# 3                 1957.50          8736.80  7928.40      1291.00     6193.20
# 4                 1948.82          8625.69  7963.86      1304.56     6164.66
#
#    Health_Care  Materials  Information_Technology  YYYYMM
# ...

# %%
joined_ASX_sector_data_rows = joined_ASX_sector_data_rows.set_index('Date')
joined_ASX_sector_data_rows.head()
# Out:
#             Utilities  Telecommunication_Services  Industrials  \
# Date
# 12/31/2015    6942.44                     2026.07      4861.33
# 12/30/2015    6927.01                     2026.84      4858.99
# 12/29/2015    6886.45                     2000.18      4805.28
# 12/28/2015    6817.50                     1979.60      4765.90
# 12/24/2015    6859.54                     1974.40      4770.85
#
#             Consumer_Discretionary  Consumer_Staple   Energy  Real Estate  \
# Date
# 12/31/2015                 1995.41          8788.40  8009.88      1291.22
# 12/30/2015                 2002.47          8870.64  8079.95      1313.87
# 12/29/2015                 1985.36          8829.02  7969.35      1309.21
# 12/28/2015                 1957.50          8736.80  7928.40      1291.00
# 12/24/2015                 1948.82          8625.69  7963.86      1304.56
#
#             Financials  Health_Care  Materials  Information_Technology  YYYYMM
# Date
# ...

# %%
#Change data type to numeric
joined_ASX_sector_data_rows['YYYYMM'] = pd.to_numeric(joined_ASX_sector_data_rows['YYYYMM'], errors='coerce')

# %%
joined_ASX_sector_data_rows.dtypes
# Out:
# Utilities                     float64
# Telecommunication_Services    float64
# Industrials                   float64
# Consumer_Discretionary        float64
# Consumer_Staple               float64
# Energy                        float64
# Real Estate                   float64
# Financials                    float64
# Health_Care                   float64
# Materials                     float64
# Information_Technology        float64
# YYYYMM                          int64
# dtype: object

# %%
joined_ASX_sector_data_rows_months= joined_ASX_sector_data_rows.groupby('YYYYMM').mean()
joined_ASX_sector_data_rows_months.head()
# Out:
#           Utilities  Telecommunication_Services  Industrials  \
# YYYYMM
# 200601  5659.345000                 1463.315000  5431.615000
# 200602  5860.095000                 1442.095000  5324.240000
# 200603  5989.939130                 1364.947826  5489.300000
# 200604  6021.035294                 1358.405882  5548.311765
# 200605  5822.434783                 1339.526087  5434.656522
#
#         Consumer_Discretionary  Consumer_Staple        Energy  Real Estate  \
# YYYYMM
# 200601             2233.365000      5969.645000  11683.520000  1903.880000
# 200602             2216.800000      5898.920000  11536.715000  1915.445000
# 200603             2330.091304      6090.221739  11737.313043  1951.900000
# 200604             2384.252941      6183.676471  12746.747059  1942.882353
# 200605             2362.543478      6214.708696  12506.665217  1935.952174
#
#          Financials  Health_Care     Materials  Information_Technology
# YYYYMM
# ...

# %%
daily_returns_asx = joined_ASX_sector_data_rows_months.pct_change()
daily_returns_asx.head()
# Out:
#         Utilities  Telecommunication_Services  Industrials  \
# YYYYMM
# 200601        NaN                         NaN          NaN
# 200602   0.035472                   -0.014501    -0.019769
# 200603   0.022157                   -0.053497     0.031002
# 200604   0.005191                   -0.004793     0.010750
# 200605  -0.032984                   -0.013898    -0.020485
#
#         Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# YYYYMM
# 200601                     NaN              NaN       NaN          NaN
# 200602               -0.007417        -0.011847 -0.012565     0.006074
# 200603                0.051106         0.032430  0.017388     0.019032
# 200604                0.023244         0.015345  0.086002    -0.004620
# 200605               -0.009105         0.005018 -0.018835    -0.003567
#
#         Financials  Health_Care  Materials  Information_Technology
# YYYYMM
# 200601         NaN          NaN        NaN                     NaN
# ...

# %%
# Set the file path
csv_path2 = Path("others_data/rba_sorted_clean.csv")

#set df
rba_sorted_clean_df = pd.read_csv(csv_path2, index_col="Effective date")

#test
rba_sorted_clean_df.head()
# Out:
#                 Change  Cash Rate Target
# Effective date
# 2006-02-08        0.00              5.50
# 2006-03-08        0.00              5.50
# 2006-04-05        0.00              5.50
# 2006-05-03        0.25              5.75
# 2006-06-07        0.00              5.75

# %%
rba_sorted_clean_df = rba_sorted_clean_df.reset_index()
rba_sorted_clean_df.head()
# Out:
#   Effective date  Change  Cash Rate Target
# 0     2006-02-08    0.00              5.50
# 1     2006-03-08    0.00              5.50
# 2     2006-04-05    0.00              5.50
# 3     2006-05-03    0.25              5.75
# 4     2006-06-07    0.00              5.75

# %%
df_split = rba_sorted_clean_df["Effective date"].str.split('-', expand=True)
#
df_split['leftpad'] = df_split[1].str.pad(side='left', fillchar='0', width = 2)
#
df_split["YYYYMM"] = df_split[0] + df_split['leftpad']
#
df_split
#joined_ASX_sector_data_rows and YYYYMM
rba_sorted_clean_yyyymm = df_split["YYYYMM"]
rba_sorted_clean_yyyymm.head()
# Out:
# 0    200602
# 1    200603
# 2    200604
# 3    200605
# 4    200606
# Name: YYYYMM, dtype: object

# %%
rba_yyyymm = pd.concat([rba_sorted_clean_df, rba_sorted_clean_yyyymm], axis=1, join='inner')
rba_yyyymm.head()
# Out:
#   Effective date  Change  Cash Rate Target  YYYYMM
# 0     2006-02-08    0.00              5.50  200602
# 1     2006-03-08    0.00              5.50  200603
# 2     2006-04-05    0.00              5.50  200604
# 3     2006-05-03    0.25              5.75  200605
# 4     2006-06-07    0.00              5.75  200606

# %%
#Change data type to numeric
rba_yyyymm['YYYYMM'] = pd.to_numeric(rba_yyyymm['YYYYMM'], errors='coerce')
rba_yyyymm.head()
# Out:
#   Effective date  Change  Cash Rate Target  YYYYMM
# 0     2006-02-08    0.00              5.50  200602
# 1     2006-03-08    0.00              5.50  200603
# 2     2006-04-05    0.00              5.50  200604
# 3     2006-05-03    0.25              5.75  200605
# 4     2006-06-07    0.00              5.75  200606

# %%
rba_yyyymm.set_index("Effective date").head()
# Out:
#                 Change  Cash Rate Target  YYYYMM
# Effective date
# 2006-02-08        0.00              5.50  200602
# 2006-03-08        0.00              5.50  200603
# 2006-04-05        0.00              5.50  200604
# 2006-05-03        0.25              5.75  200605
# 2006-06-07        0.00              5.75  200606

# %%
rba_yyyymm.dtypes
# Out:
# Effective date       object
# Change              float64
# Cash Rate Target    float64
# YYYYMM                int64
# dtype: object

# %%
rba_yyyymm_months= rba_yyyymm.groupby('YYYYMM').mean()
rba_yyyymm_months.head()
# Out:
#         Change  Cash Rate Target
# YYYYMM
# 200602    0.00              5.50
# 200603    0.00              5.50
# 200604    0.00              5.50
# 200605    0.25              5.75
# 200606    0.00              5.75

# %%
daily_returns_rba = rba_yyyymm_months.pct_change()
daily_returns_rba.head()
# Out:
#         Change  Cash Rate Target
# YYYYMM
# 200602     NaN               NaN
# 200603     NaN          0.000000
# 200604     NaN          0.000000
# 200605     inf          0.045455
# 200606    -1.0          0.000000

# %%
daily_returns_rba.rename(columns = {'GDP per capita':'GDP per capita RBA'}, inplace = True)
daily_returns_rba.head(10)
# Out:
#         Change  Cash Rate Target
# YYYYMM
# 200602     NaN               NaN
# 200603     NaN          0.000000
# 200604     NaN          0.000000
# 200605     inf          0.045455
# 200606    -1.0          0.000000
# 200607     NaN          0.000000
# 200608     inf          0.043478
# 200609    -1.0          0.000000
# 200610     NaN          0.000000
# 200611     inf          0.041667

# %%
asx_rba_daily_returns = pd.concat([daily_returns_asx, daily_returns_rba], axis=1, join='inner')
asx_rba_daily_returns.head()
# Out:
#         Utilities  Telecommunication_Services  Industrials  \
# YYYYMM
# 200602   0.035472                   -0.014501    -0.019769
# 200603   0.022157                   -0.053497     0.031002
# 200604   0.005191                   -0.004793     0.010750
# 200605  -0.032984                   -0.013898    -0.020485
# 200606  -0.005846                   -0.033141    -0.018578
#
#         Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# YYYYMM
# 200602               -0.007417        -0.011847 -0.012565     0.006074
# 200603                0.051106         0.032430  0.017388     0.019032
# 200604                0.023244         0.015345  0.086002    -0.004620
# 200605               -0.009105         0.005018 -0.018835    -0.003567
# 200606               -0.029833        -0.004024 -0.046630     0.022224
#
#         Financials  Health_Care  Materials  Information_Technology  Change  \
# YYYYMM
# 200602    0.016897     0.019598   0.011426               -0.007843     NaN
# ...

# %%
# Set the file path
csv_path3 = Path("others_data/gdp_sorted_clean.csv")

#set df
gdp_sorted_clean_df = pd.read_csv(csv_path3, index_col="Date")

#test
gdp_sorted_clean_df.head()
# Out:
#          GDP per capita
# Date
# 2006-03           12353
# 2006-06           12520
# 2006-09           12764
# 2006-12           13050
# 2007-03           13293

# %%
gdp_sorted_clean_df = gdp_sorted_clean_df.reset_index()
gdp_sorted_clean_df.head()
# Out:
#       Date  GDP per capita
# 0  2006-03           12353
# 1  2006-06           12520
# 2  2006-09           12764
# 3  2006-12           13050
# 4  2007-03           13293

# %%
df_split = gdp_sorted_clean_df["Date"].str.split('-', expand=True)
#
df_split['leftpad'] = df_split[1].str.pad(side='left', fillchar='0', width = 2)
#
df_split["YYYYMM"] = df_split[0] + df_split['leftpad']
#
df_split
#joined_ASX_sector_data_rows and YYYYMM
gdp_sorted_clean_yyyymm = df_split["YYYYMM"]
gdp_sorted_clean_yyyymm.head()
# Out:
# 0    200603
# 1    200606
# 2    200609
# 3    200612
# 4    200703
# Name: YYYYMM, dtype: object

# %%
gdp_yyyymm = pd.concat([gdp_sorted_clean_df, gdp_sorted_clean_yyyymm], axis=1)
gdp_yyyymm.head()
# Out:
#       Date  GDP per capita  YYYYMM
# 0  2006-03           12353  200603
# 1  2006-06           12520  200606
# 2  2006-09           12764  200609
# 3  2006-12           13050  200612
# 4  2007-03           13293  200703

# %%
#Change data type to numeric
gdp_yyyymm['YYYYMM'] = pd.to_numeric(gdp_yyyymm['YYYYMM'], errors='coerce')
gdp_yyyymm.head()
# Out:
#       Date  GDP per capita  YYYYMM
# 0  2006-03           12353  200603
# 1  2006-06           12520  200606
# 2  2006-09           12764  200609
# 3  2006-12           13050  200612
# 4  2007-03           13293  200703

# %%
gdp_yyyymm.set_index("Date").head()
# Out:
#          GDP per capita  YYYYMM
# Date
# 2006-03           12353  200603
# 2006-06           12520  200606
# 2006-09           12764  200609
# 2006-12           13050  200612
# 2007-03           13293  200703

# %%
gdp_yyyymm.dtypes
# Out:
# Date              object
# GDP per capita     int64
# YYYYMM             int64
# dtype: object

# %%
gdp_yyyymm_months= gdp_yyyymm.groupby('YYYYMM').mean()
gdp_yyyymm.head()
# Out:
#       Date  GDP per capita  YYYYMM
# 0  2006-03           12353  200603
# 1  2006-06           12520  200606
# 2  2006-09           12764  200609
# 3  2006-12           13050  200612
# 4  2007-03           13293  200703

# %%
daily_returns_gdp = gdp_yyyymm_months.pct_change()
daily_returns_gdp.head()
# Out:
#         GDP per capita
# YYYYMM
# 200603             NaN
# 200606        0.013519
# 200609        0.019489
# 200612        0.022407
# 200703        0.018621

# %%
asx_gdp_rba_daily_returns = pd.concat([asx_rba_daily_returns, daily_returns_gdp], axis=1, join='inner')
asx_gdp_rba_daily_returns.head()
# Out:
#         Utilities  Telecommunication_Services  Industrials  \
# YYYYMM
# 200603   0.022157                   -0.053497     0.031002
# 200606  -0.005846                   -0.033141    -0.018578
# 200609   0.045432                   -0.004321     0.036722
# 200612   0.041306                    0.067537     0.055672
# 200703  -0.029482                   -0.014974    -0.010265
#
#         Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# YYYYMM
# 200603                0.051106         0.032430  0.017388     0.019032
# 200606               -0.029833        -0.004024 -0.046630     0.022224
# 200609                0.039031         0.080020 -0.079176     0.021325
# 200612                0.033920         0.034344  0.019267     0.019944
# 200703               -0.003703         0.041279 -0.005253    -0.053265
#
#         Financials  Health_Care  Materials  Information_Technology  Change  \
# YYYYMM
# 200603    0.019872     0.054804   0.013045                0.019079     NaN
# ...

# %%
# Set the file path
csv_path4 = Path("data/Unemployment06_15_rate - Chart 1 - Unemployment rate, Australia, August 1966 to March 2022, Seasonally adjusted.csv")

#set df
Unemployment_rate_df = pd.read_csv(csv_path4, index_col="Date")

#test
Unemployment_rate_df.head()
# Out:
#             Unemployment Rate
# Date
# 2006-01-08                5.2
# 2006-02-08                5.1
# 2006-03-08                4.9
# 2006-04-05                5.0
# 2006-05-03                4.8

# %%
Unemployment_rate_df = Unemployment_rate_df.reset_index()
Unemployment_rate_df.head()
# Out:
#          Date  Unemployment Rate
# 0  2006-01-08                5.2
# 1  2006-02-08                5.1
# 2  2006-03-08                4.9
# 3  2006-04-05                5.0
# 4  2006-05-03                4.8

# %%
df_split = Unemployment_rate_df["Date"].str.split('-', expand=True)
#
df_split['leftpad'] = df_split[1].str.pad(side='left', fillchar='0', width = 2)
#
df_split["YYYYMM"] = df_split[0] + df_split['leftpad']
#
df_split
#joined_ASX_sector_data_rows and YYYYMM
Unemployment_rate_yyyymm = df_split["YYYYMM"]
Unemployment_rate_yyyymm.head()
# Out:
# 0    200601
# 1    200602
# 2    200603
# 3    200604
# 4    200605
# Name: YYYYMM, dtype: object

# %%
Unemployment_yyyymm = pd.concat([Unemployment_rate_df, Unemployment_rate_yyyymm], axis=1)
Unemployment_yyyymm.head()
# Out:
#          Date  Unemployment Rate  YYYYMM
# 0  2006-01-08                5.2  200601
# 1  2006-02-08                5.1  200602
# 2  2006-03-08                4.9  200603
# 3  2006-04-05                5.0  200604
# 4  2006-05-03                4.8  200605

# %%
#Change data type to numeric
Unemployment_yyyymm['YYYYMM'] = pd.to_numeric(Unemployment_yyyymm['YYYYMM'], errors='coerce')
Unemployment_yyyymm.head()
# Out:
#          Date  Unemployment Rate  YYYYMM
# 0  2006-01-08                5.2  200601
# 1  2006-02-08                5.1  200602
# 2  2006-03-08                4.9  200603
# 3  2006-04-05                5.0  200604
# 4  2006-05-03                4.8  200605

# %%
Unemployment_yyyymm.set_index("Date").head()
# Out:
#             Unemployment Rate  YYYYMM
# Date
# 2006-01-08                5.2  200601
# 2006-02-08                5.1  200602
# 2006-03-08                4.9  200603
# 2006-04-05                5.0  200604
# 2006-05-03                4.8  200605

# %%
Unemployment_yyyymm.dtypes
# Out:
# Date                  object
# Unemployment Rate    float64
# YYYYMM                 int64
# dtype: object

# %%
Unemployment_yyyymm= Unemployment_yyyymm.groupby('YYYYMM').mean()
Unemployment_yyyymm.head()
# Out:
#         Unemployment Rate
# YYYYMM
# 200601                5.2
# 200602                5.1
# 200603                4.9
# 200604                5.0
# 200605                4.8

# %%
daily_returns_unemploy = Unemployment_yyyymm.pct_change()
daily_returns_unemploy.head()
# Out:
#         Unemployment Rate
# YYYYMM
# 200601                NaN
# 200602          -0.019231
# 200603          -0.039216
# 200604           0.020408
# 200605          -0.040000

# %%
asx_gdp_rba_unemploy_daily_returns = pd.concat([asx_rba_daily_returns, daily_returns_unemploy], axis=1, join='inner')
asx_gdp_rba_unemploy_daily_returns.head()
# Out:
#         Utilities  Telecommunication_Services  Industrials  \
# YYYYMM
# 200602   0.035472                   -0.014501    -0.019769
# 200603   0.022157                   -0.053497     0.031002
# 200604   0.005191                   -0.004793     0.010750
# 200605  -0.032984                   -0.013898    -0.020485
# 200606  -0.005846                   -0.033141    -0.018578
#
#         Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# YYYYMM
# 200602               -0.007417        -0.011847 -0.012565     0.006074
# 200603                0.051106         0.032430  0.017388     0.019032
# 200604                0.023244         0.015345  0.086002    -0.004620
# 200605               -0.009105         0.005018 -0.018835    -0.003567
# 200606               -0.029833        -0.004024 -0.046630     0.022224
#
#         Financials  Health_Care  Materials  Information_Technology  Change  \
# YYYYMM
# 200602    0.016897     0.019598   0.011426               -0.007843     NaN
# ...

# %%
correlation = asx_rba_daily_returns.corr()
correlation
# Out:
#                             Utilities  Telecommunication_Services  \
# Utilities                    1.000000                    0.408726
# Telecommunication_Services   0.408726                    1.000000
# Industrials                  0.600868                    0.229063
# Consumer_Discretionary       0.559356                    0.261967
# Consumer_Staple              0.579787                    0.344449
# Energy                       0.366935                    0.159489
# Real Estate                  0.562463                    0.342120
# Financials                   0.647814                    0.349126
# Health_Care                  0.437515                    0.390107
# Materials                    0.418594                    0.281877
# Information_Technology       0.352949                    0.136622
# Change                      -0.384512                   -0.113449
# Cash Rate Target             0.038898                   -0.085908
#
# ...

# %%
correlation.hvplot.heatmap(
    x='columns', 
    y="index", 
    title='ASX Monthly index averages 2006 to 2015', 
    cmap=["#75968f", "#a5bab7", "#c9d9d3", "#e2e2e2", "#dfccce", "#ddb7b1", "#cc7878", "#933b41", "#550b1d"], 
    xaxis='top', 
    rot=70,
    width=1200, height=900).opts(
    toolbar=None, 
    fontsize={'title': 10, 'xticks': 8, 'yticks': 5}
)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
asx_gdp_rba_unemploy_daily_returns.dtypes
# Out:
# Utilities                     float64
# Telecommunication_Services    float64
# Industrials                   float64
# Consumer_Discretionary        float64
# Consumer_Staple               float64
# Energy                        float64
# Real Estate                   float64
# Financials                    float64
# Health_Care                   float64
# Materials                     float64
# Information_Technology        float64
# Change                        float64
# Cash Rate Target              float64
# Unemployment Rate             float64
# dtype: object

# %%
asx_gdp_rba_unemploy_daily_returns = asx_gdp_rba_unemploy_daily_returns.reset_index()

# %%
asx_gdp_rba_unemploy_daily_returns.dtypes
# Out:
# YYYYMM                          int64
# Utilities                     float64
# Telecommunication_Services    float64
# Industrials                   float64
# Consumer_Discretionary        float64
# Consumer_Staple               float64
# Energy                        float64
# Real Estate                   float64
# Financials                    float64
# Health_Care                   float64
# Materials                     float64
# Information_Technology        float64
# Change                        float64
# Cash Rate Target              float64
# Unemployment Rate             float64
# dtype: object

# %%
asx_gdp_rba_unemploy_daily_returns['YYYYMM'] = asx_gdp_rba_unemploy_daily_returns['YYYYMM'].astype(str)

# %%
df_split = asx_gdp_rba_unemploy_daily_returns["YYYYMM"].str.split('', expand=True)

df_split["YYYY"] = df_split[1] + df_split[2] + df_split[3] + df_split[4]
df_split
# Out:
#     0   1  2  3  4  5  6 7   YYYY
# 0       2  0  0  6  0  2     2006
# 1       2  0  0  6  0  3     2006
# 2       2  0  0  6  0  4     2006
# 3       2  0  0  6  0  5     2006
# 4       2  0  0  6  0  6     2006
# ..  .. .. .. .. .. .. .. ..   ...
# 105     2  0  1  5  0  8     2015
# 106     2  0  1  5  0  9     2015
# 107     2  0  1  5  1  0     2015
# 108     2  0  1  5  1  1     2015
# 109     2  0  1  5  1  2     2015
#
# [110 rows x 9 columns]

# %%
#joined_ASX_sector_data_rows and YYYYMM
asx_gdp_rba_unemploy_daily_returns_yyyy = df_split["YYYY"]
asx_gdp_rba_unemploy_daily_returns_yyyy.head()
# Out:
# 0    2006
# 1    2006
# 2    2006
# 3    2006
# 4    2006
# Name: YYYY, dtype: object

# %%
asx_gdp_rba_unemploy_daily_returns
# Out:
#      YYYYMM  Utilities  Telecommunication_Services  Industrials  \
# 0    200602   0.035472                   -0.014501    -0.019769
# 1    200603   0.022157                   -0.053497     0.031002
# 2    200604   0.005191                   -0.004793     0.010750
# 3    200605  -0.032984                   -0.013898    -0.020485
# 4    200606  -0.005846                   -0.033141    -0.018578
# ..      ...        ...                         ...          ...
# 105  201508   0.019015                   -0.026797    -0.021706
# 106  201509  -0.028246                   -0.076087    -0.018156
# 107  201510   0.039484                   -0.005786     0.041826
# 108  201511   0.025294                   -0.032687     0.023167
# 109  201512  -0.018317                    0.014249    -0.020541
#
#      Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# 0                 -0.007417        -0.011847 -0.012565     0.006074
# ...

# %%
asx_gdp_rba_unemploy_daily_yyyy = pd.concat([asx_gdp_rba_unemploy_daily_returns, asx_gdp_rba_unemploy_daily_returns_yyyy], axis=1, join='inner')
asx_gdp_rba_unemploy_daily_returns.head()
# Out:
#    YYYYMM  Utilities  Telecommunication_Services  Industrials  \
# 0  200602   0.035472                   -0.014501    -0.019769
# 1  200603   0.022157                   -0.053497     0.031002
# 2  200604   0.005191                   -0.004793     0.010750
# 3  200605  -0.032984                   -0.013898    -0.020485
# 4  200606  -0.005846                   -0.033141    -0.018578
#
#    Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  Financials  \
# 0               -0.007417        -0.011847 -0.012565     0.006074    0.016897
# 1                0.051106         0.032430  0.017388     0.019032    0.019872
# 2                0.023244         0.015345  0.086002    -0.004620    0.026731
# 3               -0.009105         0.005018 -0.018835    -0.003567   -0.006662
# 4               -0.029833        -0.004024 -0.046630     0.022224   -0.030334
#
#    Health_Care  Materials  Information_Technology  Change  Cash Rate Target  \
# ...

# %%
#Change data type to numeric
asx_gdp_rba_unemploy_daily_yyyy['YYYY'] = pd.to_numeric(asx_gdp_rba_unemploy_daily_yyyy['YYYY'], errors='coerce')
asx_gdp_rba_unemploy_daily_yyyy.head()
# Out:
#    YYYYMM  Utilities  Telecommunication_Services  Industrials  \
# 0  200602   0.035472                   -0.014501    -0.019769
# 1  200603   0.022157                   -0.053497     0.031002
# 2  200604   0.005191                   -0.004793     0.010750
# 3  200605  -0.032984                   -0.013898    -0.020485
# 4  200606  -0.005846                   -0.033141    -0.018578
#
#    Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  Financials  \
# 0               -0.007417        -0.011847 -0.012565     0.006074    0.016897
# 1                0.051106         0.032430  0.017388     0.019032    0.019872
# 2                0.023244         0.015345  0.086002    -0.004620    0.026731
# 3               -0.009105         0.005018 -0.018835    -0.003567   -0.006662
# 4               -0.029833        -0.004024 -0.046630     0.022224   -0.030334
#
#    Health_Care  Materials  Information_Technology  Change  Cash Rate Target  \
# ...

# %%
asx_gdp_rba_unemploy_daily_yyyy = asx_gdp_rba_unemploy_daily_yyyy.drop('YYYYMM', axis=1)

asx_gdp_rba_unemploy_daily_yyyy.head()
# Out:
#    Utilities  Telecommunication_Services  Industrials  Consumer_Discretionary  \
# 0   0.035472                   -0.014501    -0.019769               -0.007417
# 1   0.022157                   -0.053497     0.031002                0.051106
# 2   0.005191                   -0.004793     0.010750                0.023244
# 3  -0.032984                   -0.013898    -0.020485               -0.009105
# 4  -0.005846                   -0.033141    -0.018578               -0.029833
#
#    Consumer_Staple    Energy  Real Estate  Financials  Health_Care  Materials  \
# 0        -0.011847 -0.012565     0.006074    0.016897     0.019598   0.011426
# 1         0.032430  0.017388     0.019032    0.019872     0.054804   0.013045
# 2         0.015345  0.086002    -0.004620    0.026731     0.012831   0.149380
# 3         0.005018 -0.018835    -0.003567   -0.006662    -0.017080  -0.012361
# 4        -0.004024 -0.046630     0.022224   -0.030334    -0.054345  -0.083664
#
# ...

# %%
asx_gdp_rba_unemploy_daily_yyyy= asx_gdp_rba_unemploy_daily_yyyy.groupby('YYYY').mean()
asx_gdp_rba_unemploy_daily_yyyy.head()
# Out:
#       Utilities  Telecommunication_Services  Industrials  \
# YYYY
# 2006   0.016333                   -0.001553     0.012372
# 2007  -0.007316                    0.009426     0.005529
# 2008  -0.033483                   -0.016707    -0.056456
# 2009   0.000860                   -0.004742     0.022419
# 2010   0.003406                   -0.016283    -0.005332
# 2011   0.003081                    0.013066    -0.008071
# 2012   0.010724                    0.024784     0.000710
# 2013  -0.000095                    0.012958     0.005389
# 2014   0.008198                    0.010491     0.007219
# 2015   0.009914                   -0.007955     0.009384
#
#       Consumer_Discretionary  Consumer_Staple    Energy  Real Estate  \
# YYYY
# 2006                0.019092         0.016537  0.001985     0.017036
# 2007               -0.001169         0.019220  0.023412    -0.005017
# 2008               -0.067030        -0.028439 -0.012525    -0.059255
# ...

# %%
asx_gdp_rba_unemploy_daily_yyyy = asx_gdp_rba_unemploy_daily_yyyy.reset_index()

# %%
Utilities	Telecommunication_Services	Industrials	Consumer_Discretionary	Consumer_Staple	Energy	Real Estate	Financials	Health_Care	Materials	Information_Technology	Change	Cash Rate Target	Unemployment Rate

# %%
asx_gdp_rba_unemploy_daily_returns.hvplot(x='YYYYMM', y=['Telecommunication_Services', 'Industrials', 'Consumer_Discretionary', 'Consumer_Staple', 'Energy',
                                                   'Real Estate', 'Financials', 'Health_Care','Materials', 'Information_Technology', 'Utilities', 'Cash Rate Target'], width=1000, height=600)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [YYYYMM]   (value)
