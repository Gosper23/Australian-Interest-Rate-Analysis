# %%
# Initial imports
import pandas as pd
from pathlib import Path

# %%
csv_path = Path("data/dwelling_types_syd_LGA.csv")
dwelling_types_syd_LGA_df = pd.read_csv(csv_path, header=0)
dwelling_types_syd_LGA_df.head()
# Out:
#   Local Government Areas  Separate house  \
# 0           Rockdale (C)           18402
# 1          Blacktown (C)           77966
# 2            Burwood (A)            6300
# 3             Camden (A)           15882
# 4       Campbelltown (C)           40117
#
#    Semi-detached, row or terrace house, townhouse etc with one storey  \
# 0                                               3623
# 1                                               4762
# 2                                                744
# 3                                                435
# 4                                               4450
#
#    Semi-detached, row or terrace house, townhouse etc with two or more storeys  \
# 0                                               1333
# 1                                               5301
# 2                                                389
# 3                                                199
# 4                                               4029
#
# ...

# %%
# Check for null values
dwelling_types_syd_LGA_df.isnull()
# Out:
#     Local Government Areas  Separate house  \
# 0                    False           False
# 1                    False           False
# 2                    False           False
# 3                    False           False
# 4                    False           False
# 5                    False           False
# 6                    False           False
# 7                    False           False
# 8                    False           False
# 9                    False           False
# 10                   False           False
# 11                   False           False
# 12                   False           False
# 13                   False           False
# 14                   False           False
# 15                   False           False
# 16                   False           False
# 17                   False           False
# 18                   False           False
# 19                   False           False
# 20                   False           False
# ...

# %%
# Determine number of nulls
dwelling_types_syd_LGA_df.isnull().sum()
# Out:
# Local Government Areas                                                         0
# Separate house                                                                 0
# Semi-detached, row or terrace house, townhouse etc with one storey             0
# Semi-detached, row or terrace house, townhouse etc with two or more storeys    0
# Flat, unit or apartment in a one or two storey block                           0
# Flat, unit or apartment in a three storey block                                0
# Flat, unit or apartment in a four or more storey block                         0
# Flat, unit or apartment attached to a house                                    0
# Total                                                                          0
# dtype: int64

# %%
# Check duplicates
dwelling_types_syd_LGA_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# dtype: bool

# %%
csv_path = Path("data/tenure_type_syd_LGA.csv")
tenure_type_syd_LGA_df = pd.read_csv(csv_path, header=0)
tenure_type_syd_LGA_df.head()
# Out:
#   Local Government Areas  Fully owned  Being purchased  \
# 0           Rockdale (C)        12312             8713
# 1          Blacktown (C)        20946            35383
# 2            Burwood (A)         3701             2399
# 3             Camden (A)         4042             8107
# 4       Campbelltown (C)        10842            19076
#
#    Being purchased under a rent/buy scheme  Rented  Total
# 0                                       61   10287  31368
# 1                                      229   26029  82582
# 2                                       33    3625   9753
# 3                                       19    2961  15136
# 4                                      111   14252  44288

# %%
# Check for null values
tenure_type_syd_LGA_df.isnull()
# Out:
#     Local Government Areas  Fully owned  Being purchased  \
# 0                    False        False            False
# 1                    False        False            False
# 2                    False        False            False
# 3                    False        False            False
# 4                    False        False            False
# 5                    False        False            False
# 6                    False        False            False
# 7                    False        False            False
# 8                    False        False            False
# 9                    False        False            False
# 10                   False        False            False
# 11                   False        False            False
# 12                   False        False            False
# 13                   False        False            False
# 14                   False        False            False
# ...

# %%
# Determine number of nulls
tenure_type_syd_LGA_df.isnull().sum()
# Out:
# Local Government Areas                     0
# Fully owned                                0
# Being purchased                            0
# Being purchased under a rent/buy scheme    0
# Rented                                     0
# Total                                      0
# dtype: int64

# %%
# Check duplicates
tenure_type_syd_LGA_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# dtype: bool

# %%
csv_path = Path("data/Loan_repay_range_syd_LGA.csv")
Loan_repay_range_syd_LGA_df = pd.read_csv(csv_path, header=0)
Loan_repay_range_syd_LGA_df.head()
# Out:
#   Local Government Areas  $1 - $99  $100 - $149  $150 - $249  $250 - $399  \
# 0           Rockdale (C)        50           18           59          125
# 1          Blacktown (C)       223           92          224          485
# 2            Burwood (A)        15            0           17           35
# 3             Camden (A)        30           10           36           91
# 4       Campbelltown (C)        80           52          174          275
#
#    $400 - $549  $550 - $649  $650 - $749  $750 - $849  $850 - $949  ...  \
# 0          224           83          187          179          266  ...
# 1         1006          524          932          825         1224  ...
# 2           74           31           42           58           66  ...
# 3          165          110          157          161          253  ...
# 4          684          374          648          594          929  ...
#
#    $1,200 - $1,399  $1,400 - $1,599  $1,600 - $1,999  $2,000 - $2,399  \
# ...

# %%
# Check for null values
Loan_repay_range_syd_LGA_df.isnull()
# Out:
#     Local Government Areas  $1 - $99  $100 - $149  $150 - $249  $250 - $399  \
# 0                    False     False        False        False        False
# 1                    False     False        False        False        False
# 2                    False     False        False        False        False
# 3                    False     False        False        False        False
# 4                    False     False        False        False        False
# 5                    False     False        False        False        False
# 6                    False     False        False        False        False
# 7                    False     False        False        False        False
# 8                    False     False        False        False        False
# 9                    False     False        False        False        False
# 10                   False     False        False        False        False
# ...

# %%
# Determine number of nulls
Loan_repay_range_syd_LGA_df.isnull().sum()
# Out:
# Local Government Areas    0
# $1 - $99                  0
# $100 - $149               0
# $150 - $249               0
# $250 - $399               0
# $400 - $549               0
# $550 - $649               0
# $650 - $749               0
# $750 - $849               0
# $850 - $949               0
# $950 - $1,049             0
# $1,050 - $1,199           0
# $1,200 - $1,399           0
# $1,400 - $1,599           0
# $1,600 - $1,999           0
# $2,000 - $2,399           0
# $2,400 - $2,999           0
# $3,000 - $3,999           0
# $4,000 and over           0
# Not stated                0
# Not applicable            0
# Total                     0
# dtype: int64

# %%
# Check duplicates
Loan_repay_range_syd_LGA_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# dtype: bool

# %%
csv_path = Path("data/rent_range_syd_LGA.csv")
rent_range_syd_LGA_df = pd.read_csv(csv_path, header=0)
rent_range_syd_LGA_df.head()
# Out:
#   Local Government Areas  $0 - $49  $50 - $74  $75 - $99  $100 - $119  \
# 0           Rockdale (C)       338        315        163          200
# 1          Blacktown (C)       666       2046       1398         1387
# 2            Burwood (A)       147        148         69           67
# 3             Camden (A)       128        113         55           68
# 4       Campbelltown (C)       370       1187       1081          890
#
#    $120 - $139  $140 - $159  $160 - $179  $180 - $199  $200 - $224  \
# 0          167          171          213          435         1382
# 1         1057         1052         1529         2405         4374
# 2           52           49           77          111          272
# 3           58           96           64           81          269
# 4          676          818         1358         1746         2753
#
#    $225 - $249  $250 - $274  $275 - $299  $300 - $349  $350 - $449  \
# 0         1157         1414          893         1793         1253
# ...

# %%
# Check for null values
rent_range_syd_LGA_df.isnull()
# Out:
#     Local Government Areas  $0 - $49  $50 - $74  $75 - $99  $100 - $119  \
# 0                    False     False      False      False        False
# 1                    False     False      False      False        False
# 2                    False     False      False      False        False
# 3                    False     False      False      False        False
# 4                    False     False      False      False        False
# 5                    False     False      False      False        False
# 6                    False     False      False      False        False
# 7                    False     False      False      False        False
# 8                    False     False      False      False        False
# 9                    False     False      False      False        False
# 10                   False     False      False      False        False
# 11                   False     False      False      False        False
# ...

# %%
# Determine number of nulls
rent_range_syd_LGA_df.isnull().sum()
# Out:
# Local Government Areas    0
# $0 - $49                  0
# $50 - $74                 0
# $75 - $99                 0
# $100 - $119               0
# $120 - $139               0
# $140 - $159               0
# $160 - $179               0
# $180 - $199               0
# $200 - $224               0
# $225 - $249               0
# $250 - $274               0
# $275 - $299               0
# $300 - $349               0
# $350 - $449               0
# $450 - $549               0
# $550 and over             0
# Not stated                0
# Not applicable            0
# Total                     0
# dtype: int64

# %%
# Check duplicates
rent_range_syd_LGA_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# dtype: bool
